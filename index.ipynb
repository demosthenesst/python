# %% [markdown]
# # Φύλλα δραστηριοτήτων Μαθηματικών με python

# %% [markdown]
# ## Πίνακας Περιεχομένων
#
# ### A Γυμνασίου
#
# 1. [Εξισώσεις](equations-a.ipynb)
# 1. [Πρόσθεση θετικών-αρνητικών αριθμών](addition.ipynb)
# 1. [Αφαίρεση θετικών-αρνητικών αριθμών](subtraction.ipynb)
#
# ### Β Γυμνασίου
#
# 1. [Πείραμα τύχης: ρίψη ζαριού](die_roll.ipynb)
# 1. [Πείραμα τύχης: ρίψη ζεύγους ζαριών](two_dice_roll.ipynb)
#
# ### Β Λυκείου
# 1. [Διαίρεση πολυωνύμων - εξάσκηση](poly_division.ipynb)
# 1. [Σχήμα Horner](horner.ipynb)
# 1. [Εξάσκηση στο σχήμα Horner](horner_practice.ipynb)
#
# <br>
# <br>
# <img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM.png" width="150">
